# %%
Aim of project  is we make to read comment to easy and also read all comment in same page  itself.

# %%
#Import necessary library
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
#pip install
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask_cors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#searching product 
searchstring = "iphone11"

# %%
#searching product using flipkart url
flipkart_url = "https://www.flipkart.com/search?q="+ searchstring

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
uclient = uReq(flipkart_url)

# %%
uclient

# %%
#To read flipkatpage
flipkartpage = uclient.read()

# %%
flipkartpage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
#using beauti soap can align html in neatly
flipkart_html = bs(flipkartpage ,"html.parser")

# %%
print(flipkart_html)
# Out:
# <!DOCTYPE html>
# ...

# %%
#full iphone11 url
'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&iid=1a7d6e12-960f-485c-8380-2cb8dc49a077.MOBFWQ6B7KKRXDDS.SEARCH&ssid=vuttur3d740000001676109727214&qH=d6db477051465f9a'
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&iid=1a7d6e12-960f-485c-8380-2cb8dc49a077.MOBFWQ6B7KKRXDDS.SEARCH&ssid=vuttur3d740000001676109727214&qH=d6db477051465f9a'

# %%
#specific division can read 
bigboxes = flipkart_html.findAll("div" , {"class": "_1AtVbE col-12-12"})

# %%
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
#total number of item
len(bigboxes)
# Out:
# 29

# %%
box = bigboxes[2]

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBFWQ6B7KKRXDDS" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&amp;lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=52be6004-b87b-41e0-8792-977ff0df2e41.MOBFWQ6B7KKRXDDS.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=6p39ysw1r40000001682057949939&amp;qH=d6db477051465f9a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 11 (White, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/k2jbyq80pkrrdj/mobile-refurbished/k/y/d/iphone-11-256-u-mwm82hn-a-apple-0-original-imafkg25mhaztxns.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2i
# ...

# %%
"https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&amp;lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=cbad50bb-39eb-4c43-8f00-5dd17e4f58ea.MOBFWQ6B7KKRXDDS.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=arzbus405c0000001676110285064&amp;qH=d6db477051465f9a"
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&amp;lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&amp;marketplace=FLIPKART&amp;q=iphone11&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=cbad50bb-39eb-4c43-8f00-5dd17e4f58ea.MOBFWQ6B7KKRXDDS.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=arzbus405c0000001676110285064&amp;qH=d6db477051465f9a'

# %%
productlink = "https://www.flipkart.com"+box.div.div.div.a['href']

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=52be6004-b87b-41e0-8792-977ff0df2e41.MOBFWQ6B7KKRXDDS.SEARCH&ppt=None&ppn=None&ssid=6p39ysw1r40000001682057949939&qH=d6db477051465f9a'

# %%
productreq = requests.get(productlink)

# %%
productreq
# Out:
# <Response [200]>

# %%
prod_html = bs(productreq.text,"html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
#rating
comment_box = prod_html.find_all("div", {"class" : "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
#looping one by one (rating star)
for i in comment_box :
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 4
# 5
# 5
# 4
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [36], line 2
#       1 for i in comment_box :
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#we can check commend specific one
comment_box[1].div.div.find_all("div" ,{"class" : ""})
# Out:
# [<div><div class="">Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .</div>,
#  <div></div>]

# %%
# we can check the commend by using looping method 
for i in comment_box : 
    print(i.div.div.find_all("div" ,{"class" : ""})[0].div.text)
    print("\n")
# Out:
# Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.
#
#
# Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .
#
#
# Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7. Pros-Camera top class - Battery top performed -Chipset no need to say as apple kind -Security as you expect from apple - Display super bright industry leading colour   accuracy and super responsive -Build quality as expect from apple sturdy  premium durable beautiful stylish. -Os most stable os in smartphone industry Cons -No 5G-Display is not based on OLED technology -Charger headphones and 1 apple stic...
#
#
# I'm Really happy with the productDelivery was fast as well..it was a gift for my sister and she loved it so much.
#
#
# ...

# %%
#Flipkart customer name specific one 
comment_box[1].div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })[0].text
# Out:
# 'Flipkart Customer'

# %%
#flipkart customer name  can exeute one by one ueing loop method
for i in comment_box:
    print(i.div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })[0].text)
# Out:
# Flipkart Customer
# Flipkart Customer
# Manish Raghuvanshi
# George Haokip
# Jimly  Gogoi
# Vamshi  Chakrala
# vijay hegde
# Chirag Rajput
# Vishal Dubey
# Rahul Verma
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [42], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'
